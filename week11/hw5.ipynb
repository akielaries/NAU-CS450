# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
xs = np.random.normal(10, 3, 10000000)
m, s = xs.mean(), xs.std()
m, s
# Out:
# (10.000175586779438, 3.0007579494708345)

# %%
ns = np.array([(x - m) / s for x in xs])
ns.mean(), ns.std()
# Out:
# (2.1634122049363214e-15, 1.0000000000000009)

# %%
h = plt.hist(ns, bins=10)
h
# Out:
# (array([6.800000e+01, 4.744000e+03, 1.114040e+05, 9.663700e+05,
#         3.114056e+06, 3.767020e+06, 1.723790e+06, 2.934870e+05,
#         1.863100e+04, 4.300000e+02]),
#  array([-5.36603041, -4.33344881, -3.30086721, -2.2682856 , -1.235704  ,
#         -0.20312239,  0.82945921,  1.86204082,  2.89462242,  3.92720403,
#          4.95978563]),
#  <BarContainer object of 10 artists>)
